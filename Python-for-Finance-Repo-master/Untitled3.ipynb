# %%
import ffn

# %%
# %matplotlib inline

# %%
prices = ffn.get('aapl,msft', start='2010-01-01')

# %%
ax = prices.rebase().plot(figsize=(10, 5))

# %%
returns = prices.to_returns().dropna()
ax = returns.hist(figsize=(10, 5))

# %% [raw]
# stats = prices.calc_stats()
# stats.display()

# %%
stats = prices.calc_stats()
stats.display()
# Out:
# Stat                 aapl        msft
# -------------------  ----------  ----------
# Start                2010-01-04  2010-01-04
# End                  2022-09-07  2022-09-07
# Risk-free rate       0.00%       0.00%
#
# Total Return         2289.82%    986.70%
# Daily Sharpe         1.03        0.86
# Daily Sortino        1.71        1.44
# CAGR                 28.46%      20.71%
# Max Drawdown         -43.80%     -29.08%
# Calmar Ratio         0.65        0.71
#
# MTD                  -0.80%      -1.29%
# 3m                   5.02%       -5.09%
# 6m                   -1.82%      -7.05%
# YTD                  -11.81%     -22.76%
# 1Y                   0.09%       -13.30%
# 3Y (ann.)            43.94%      24.58%
# 5Y (ann.)            32.45%      29.88%
# 10Y (ann.)           22.30%      26.11%
# Since Incep. (ann.)  28.46%      20.71%
#
# Daily Sharpe         1.03        0.86
# Daily Sortino        1.71        1.44
# Daily Mean (ann.)    29.10%      22.12%
# ...

# %%
stats = prices.calc_stats()
stats.display()
# Out:
# Stat                 aapl        msft
# -------------------  ----------  ----------
# Start                2010-01-04  2010-01-04
# End                  2022-09-07  2022-09-07
# Risk-free rate       0.00%       0.00%
#
# Total Return         2289.82%    986.70%
# Daily Sharpe         1.03        0.86
# Daily Sortino        1.71        1.44
# CAGR                 28.46%      20.71%
# Max Drawdown         -43.80%     -29.08%
# Calmar Ratio         0.65        0.71
#
# MTD                  -0.80%      -1.29%
# 3m                   5.02%       -5.09%
# 6m                   -1.82%      -7.05%
# YTD                  -11.81%     -22.76%
# 1Y                   0.09%       -13.30%
# 3Y (ann.)            43.94%      24.58%
# 5Y (ann.)            32.45%      29.88%
# 10Y (ann.)           22.30%      26.11%
# Since Incep. (ann.)  28.46%      20.71%
#
# Daily Sharpe         1.03        0.86
# Daily Sortino        1.71        1.44
# Daily Mean (ann.)    29.10%      22.12%
# ...

# %%
ax = stats.prices.to_drawdown_series().plot(figsize=(20,10))

# %%
data = ffn.get('btc,eth,bnb', start='2020-01-01', end='2022-01-01')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_datareader\yahoo\daily.py in _read_one_data(self, url, params)
#     152             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154         except KeyError:
#
# KeyError: 'HistoricalPriceStore'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-10-9006c4cdec1d> in <module>
# ----> 1 data = ffn.get('btc,eth,bnb', start='2020-01-01', end='2022-01-01')
#
# <decorator-gen-127> in get(tickers, provider, common_dates, forward_fill, clean_tickers, column_names, ticker_field_sep, mrefresh, existing, **kwargs)
#
# ...

# %%
print(data.head())

# %%
data = ffn.get(['BTC-USD', 'ETH-USD', 'EURUSD=X'], start='2020-01-01', end='2022-09-10')

# %%
print(data)
# Out:
#                   btcusd       ethusd   eurusdx
# Date
# 2020-01-01   7200.174316   130.802002  1.122083
# 2020-01-02   6985.470215   127.410179  1.122083
# 2020-01-03   7344.884277   134.171707  1.117144
# 2020-01-06   7769.219238   144.304153  1.116196
# 2020-01-07   8163.692383   143.543991  1.119799
# ...                  ...          ...       ...
# 2022-09-01  20127.140625  1586.176758  0.995233
# 2022-09-04  19986.712891  1577.641602  0.990943
# 2022-09-05  19812.371094  1617.183228  0.995223
# 2022-09-06  18837.667969  1561.748535  0.989795
# 2022-09-08  19298.800781  1633.922974  1.003009
#
# [702 rows x 3 columns]
