# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn

# %%
fig = plt.figure(); ax = fig.add_subplot(1,1,1)

# %%
spx = randn(1000).cumsum()

# %%
spx.plot(ax=ax, lw=1, label= "$RAND Price")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-1ee7137c569f> in <module>
# ----> 1 spx.plot(ax=ax, lw=1, label= "$RAND Price")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
ax.legend(loc='best')

# %%
fig

# %%
crisis_data = [
    ( 410, 'true bottom'),
    ( 500, 'first dip'),
    ( 800, 'second dip'),
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
               xytext = (date, spx.asof(date) + 225),
               arrowprops= dict(facecolor='black', headwidth=4, width=2, headlength=4),
               horizontalalignment='left', verticalalignment='top')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f338fa577df7> in <module>
#       6
#       7 for date, label in crisis_data:
# ----> 8     ax.annotate(label, xy=(date, ax.asof(date) + 75),
#       9                xytext = (date, ax.asof(date) + 225),
#      10                arrowprops= dict(facecolor='black', headwidth=4, width=2, headlength=4),
#
# AttributeError: 'AxesSubplot' object has no attribute 'asof'
