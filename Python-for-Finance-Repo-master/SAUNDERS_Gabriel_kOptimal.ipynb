# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn import datasets

# %%
#EXERCICE 1 :

# %%
 plt.show()

# %%
#Exercice :

#2)a.

#We create a sample dataset with the make_blobs function
n_samples = 2000
random_state = 14
X, y = make_blobs(n_samples=n_samples, random_state=random_state)

#We print it's shape
print("shape = " + str(X.shape))

#We use kmeans and fit our model 
model = KMeans(n_clusters=3, n_init=10)
model.fit(X)
model.predict(X)

#Now we print out the inertia of our model 
print("inertia = " + str(model.inertia_))

#Let's make a scatterpoint chart to represent our centroids 
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], c = "r")
# Out:
# shape = (2000, 2)
# inertia = 4126.9583327073415

# %%
k = 20
curve_inertia(X, k)

# %%
#We can deduce based on both charts that the best value for k is 3.

# %%
#Exercice 
#2)b.

#We create a dataset using the function load_iris
n_samples = 2000
random_state = 12

iris = datasets.load_iris()
X = iris.data[:, :2]  
y = iris.target

#We print it's shape
print("Shape = " + str(X.shape))

#We use kmeans and train our model
model = KMeans(n_clusters=3, n_init=10)
model.fit(X)
model.predict(X)


#We print out the inertia 
print("inertie = " + str(model.inertia_))

#Let's make a scatterpoint chart to represent our centroids 
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], c = "r")
# Out:
# Shape = (150, 2)
# inertie = 37.0507021276596

# %%
k = 20
curve_inertia(X, k)
