# %%
#sklearn import
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
        
#matplotlib import
import matplotlib.pyplot as plt
import numpy as np

# %%
#Charger le dataset IRIS
diabetes = datasets.load_diabetes()
       
X = diabetes.data
y = diabetes.target
print("Shape of diabetes dataset = " + str(diabetes.data.shape))
print("Dataset column : " + str(diabetes.feature_names))
       
plt.scatter(X[:,2], y)
# Out:
# Shape of diabetes dataset = (442, 10)
# Dataset column : ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
#On va faire une étude des K Plus Proche Voisins
#We will do a study of the K Nearest Neighbors

# %%
#On sépare le dataset avec 75% d'entraînement et 25% de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
plt.plot(X_train[:,2], y_train, 'o', label='train')
plt.plot(X_test[:,2], y_test, 'o', label='test')
plt.legend(loc='best')

# %%
 #Entraînement d'une régression linéaire et évaluation de la régression linéaire

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred_train = knn.predict(X_train)
#On affiche un nuage de point avec les données train, test et les données prédite
plt.plot(X_train[:,2], y_train, 'o', c="green", label="train", markersize=2)
plt.plot(X_test[:,2], y_test, 'o', c="red", label='test', markersize=2)
plt.plot(X_train[:,2], y_pred_train, 's', c="blue", label="prediction")
plt.legend(loc='best')


#On affiche le score
print("Le score est de : " + str(knn.score(X_test, y_test)))
# Out:
# Le score est de : 0.44659346214225026

# %%
  "Le score est de : 0.44659346214225026\n"
# Out:
# 'Le score est de : 0.44659346214225026\n'

# %%
"Les données prédite semblent correspondre globalement aux données de train et aux données de test sur le graphique. Toutefois le score est de 0.44 ce qui signifie que seulement 44% des données sont prédite correctement.\n",
        "Le modèle est donc moyennement fiable"
# Out:
#   File "<ipython-input-8-6e07a4a1826a>", line 2
#     "Le modèle est donc moyennement fiable"
#     ^
# IndentationError: unexpected indent

# %%
 "**Affichage de l'équation linéaire**"
# Out:
# "**Affichage de l'équation linéaire**"

# %%
 "cell_type": "code",
      "source": [
        "#Crée l'objet\n",
        "regr = linear_model.LinearRegression()\n",
        "\n",
        "# Entraîne l'objet\n",
        "regr.fit(X_train, y_train)\n",
        "\n",
        "# On fait des prédictions\n",
        "diabetes_y_pred = regr.predict(X_test)\n",
        "\n",
        "#Une équation linéaire s'écrit de la manière suivante : Y = aX + b\n",
        "#ou a correspond aux coefficients \n",
        "print(\"Coefficient : \" + str(regr.coef_))\n",
        "#et b correspond aux coordonnées à l'origine \n",
        "print(\"Coordonnée à l'origine : \" + str(regr.intercept_))\n",
        "\n",
        "print(\"\\nEquation : \")\n",
        "print(\"Y =\", end=\"\")\n",
        "\n",
        "#Affichons pour chaque colonne son coefficient\n",
        "x = 0\n",
        "for i in diabetes['feature_names'] :\n",
        "  print(  str(regr.coef_[x])+ \"*\"+ i   + \" + \", end=\"\")\n",
        "  x = x+1\n",
        "print(regr.intercept_)"
# Out:
#   File "<ipython-input-10-742b40158249>", line 1
#     "cell_type": "code",
#                        ^
# SyntaxError: invalid syntax

# %%
 "Coefficient : [  47.74968054 -241.99090728  531.97106288  381.56286182 -918.50290455\n",
            "  508.25778252  116.95016447  269.4923028   695.80811712   26.32458203]\n",
            "Coordonnée à l'origine : 151.6651755919933\n",
            "\n",
            "Equation : \n",
            "Y =47.74968054051904*age + -241.99090727900375*sex + 531.9710628796015*bmi + 381.56286182427385*bp + -918.5029045531496*s1 + 508.2577825194679*s2 + 116.9501644698269*s3 + 269.4923027979242*s4 + 695.8081171154499*s5 + 26.324582028085743*s6 + 151.6651755919933\n"
# Out:
#   File "<ipython-input-11-d59a8b134f34>", line 2
#     "  508.25778252  116.95016447  269.4923028   695.80811712   26.32458203]\n",
#     ^
# IndentationError: unexpected indent
