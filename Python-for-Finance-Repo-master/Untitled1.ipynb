# %%
import pandas as pd 

df = pd.read_json('traits2.json')
df.to_csv('trait2.csv')

# %%
df
# Out:
#       Tier     Face Color            Blob Style           Face          Shape  \
# 0        4          FTXUS                 FTXUS          FTXUS          FTXUS
# 1        4  Candy Machine         Candy Machine  Candy Machine  Candy Machine
# 2        4      Cyberpunk             Cyberpunk      Cyberpunk      Cyberpunk
# 3        4            Fox                   Fox            Fox            Fox
# 4        4            FTX                   FTX            FTX            FTX
# ...    ...            ...                   ...            ...            ...
# 8073     1           Dark           Rufous Tart           Evil           Poop
# 8074     2         Bright    Liquid Inky Cherry           Melt          Bunny
# 8075     2           Dark     Liquid Ruby Taupe        Smiling          Bunny
# 8076     2           Dark  Liquid Pine Mint Tea            UwU          Round
# 8077     1         Bright         Eggplant Pine          Blush         Fluffy
#
# ...

# %% [markdown]
# ## df.count('Tier')
